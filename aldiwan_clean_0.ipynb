# %%
import json
import arabic_string as astring
from tqdm import tqdm
import string

# %%
with open("aldiwan_raw.json", "r") as f:
    aldiwan_dict = json.load(f)

# %% [markdown]
# # Inspect authors names

# %%
astring.printable
# Out:
# 'ءابتثجحخدذرزسشصضطظعغفقكلمنهويّأؤئةىآﻻإ0123456789٠١٢٣٤٥٦٧٨٩!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~٬٪٠۰٫،؛:“”–ـ…’«»؟ًٌٍؘَؙُؚِْٜ \t\n\r\x0b\x0c'

# %%
def validate_authors_names(aldiwan_dict):
    valid = True
    for author_name, _ in tqdm(aldiwan_dict.items()):
        for c in author_name:
            if c not in astring.printable:
                print(f"{author_name}: ({c})")
                valid = False
    if valid:
        print("All authors names are valid")

# %%
validate_authors_names(aldiwan_dict)
# Out:
# 100%|█████████████████████████████████████| 936/936 [00:00<00:00, 145010.47it/s]
# All authors names are valid

# %%
def validate_authors_atts(aldiwan_dict, att):
    valid = True
    for author_name, author_atts in tqdm(aldiwan_dict.items()):
        if type(author_atts[att]) != str:
            raise Exception(f"Error: attribute's '{att}' value is not a string")
        for c in author_atts[att]:
            if c not in astring.printable:
                print(f"{author_name}/{att}/{author_atts[att]}: ({c})")
                valid = False
    if valid:
        print(f"All authors {att} fields are valid")

# %%
validate_authors_atts(aldiwan_dict, "name")
# Out:
# 100%|█████████████████████████████████████| 936/936 [00:00<00:00, 124020.49it/s]
# All authors name fields are valid

# %% [markdown]
# # Validate poems attributes

# %%
def validate_poems_att(aldiwan_dict, att, verbose=0):
    valid = True
    UKT = {}
    for author_name, author_atts in tqdm(aldiwan_dict.items()):
        for poem_name, poem_atts in author_atts["poems"].items():
            if att not in poem_atts:
                continue
            for c in poem_atts[att]:
                if c not in astring.printable:
                    if c in UKT:
                        UKT[c] += 1
                    else: 
                        UKT[c] = 1
                    valid = False
                    if verbose:
                        if len(poem_atts[att]) > 20:
                            att_repr = f"{poem_atts[att][:20]}..."
                        else:
                            att_repr = poem_atts[att]

                        print("author name:", author_name)
                        print("poem name:", poem_name)
                        print("attribute:", att)
                        print("attribute value:", att_repr)
                        print("unrecognized character:", c)
                        print()
                    
    if valid and verbose:
        print(f"All poems {att} fields are valid")

    return dict(sorted(UKT.items(), key=lambda item: item[1], reverse=True))

# %%
validate_poems_att(aldiwan_dict, "genre")
# Out:
# 100%|███████████████████████████████████████| 936/936 [00:00<00:00, 7742.60it/s]
# {}

# %%
validate_poems_att(aldiwan_dict, "type")
# Out:
# 100%|██████████████████████████████████████| 936/936 [00:00<00:00, 10821.98it/s]
# {}

# %%
validate_poems_att(aldiwan_dict, "meter")
# Out:
# 100%|███████████████████████████████████████| 936/936 [00:00<00:00, 8218.03it/s]
# {}

# %%
validate_poems_att(aldiwan_dict, "rhyme")
# Out:
# 100%|███████████████████████████████████████| 936/936 [00:00<00:00, 5884.53it/s]
# {}

# %%
validate_poems_att(aldiwan_dict, "author")
# Out:
# 100%|███████████████████████████████████████| 936/936 [00:00<00:00, 7378.08it/s]
# {}

# %%
validate_poems_att(aldiwan_dict, "author")
# Out:
# 100%|███████████████████████████████████████| 936/936 [00:00<00:00, 7390.91it/s]
# {}

# %%
unknown_chars = validate_poems_att(aldiwan_dict, "text", verbose=1)
# Out:
#   5%|██                                       | 48/936 [00:00<00:03, 232.49it/s]
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: عبد العزيز المقالح
# poem name: العجوز والمقهى
# attribute: text
# attribute value: (إلى الصديق الشاعر س...
# unrecognized character: ٭
#
# author name: علي أحمد باكثير
# poem name: مآذن اسطنبول
# attribute: text
# attribute value: وكم بالآستانة من معا...
# unrecognized character:
#
# author name: علي أحمد باكثير
# poem name: مآذن اسطنبول
# attribute: text
# attribute value: وكم بالآستانة من معا...
# unrecognized character:
#
# author name: علي أحمد باكثير
# poem name: مآذن اسطنبول
# attribute: text
# attribute value: وكم بالآستانة من معا...
# unrecognized character:
#
# author name: عبد الوهاب البياتي
# poem name: أولد وأحترق
# attribute: text
# attribute value: (1)تستيقظ (لارا) في ...
# unrecognized character:
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﺛ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﺛ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻭ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: بالأخضر كفناه
# attribute: text
# attribute value: يا أُمّي تأخذني عينا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: ذهب الذين أحبهم
# attribute: text
# attribute value: جاء الشتاءُ وأنت ترت...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: ذهب الذين أحبهم
# attribute: text
# attribute value: جاء الشتاءُ وأنت ترت...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: ذهب الذين أحبهم
# attribute: text
# attribute value: جاء الشتاءُ وأنت ترت...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: ذهب الذين أحبهم
# attribute: text
# attribute value: جاء الشتاءُ وأنت ترت...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: ذهب الذين أحبهم
# attribute: text
# attribute value: جاء الشتاءُ وأنت ترت...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: ذهب الذين أحبهم
# attribute: text
# attribute value: جاء الشتاءُ وأنت ترت...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: ذهب الذين أحبهم
# attribute: text
# attribute value: جاء الشتاءُ وأنت ترت...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: ذهب الذين أحبهم
# attribute: text
# attribute value: جاء الشتاءُ وأنت ترت...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: ذهب الذين أحبهم
# attribute: text
# attribute value: جاء الشتاءُ وأنت ترت...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: ذهب الذين أحبهم
# attribute: text
# attribute value: جاء الشتاءُ وأنت ترت...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: وجهة نظر
# attribute: text
# attribute value:  قال ليعن زبد البحرب...
# unrecognized character:
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻭ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻬ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﺬ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﺍ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﺛ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﺛ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: زرقاء اليمامة
# attribute: text
# attribute value: تتدلَّى أشجارُ التين...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: لالا فاطمة
# attribute: text
# attribute value: آهْ… لالّاآهْ… لالّا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﻭ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: وكان الصيف موعدنا
# attribute: text
# attribute value: وكان الصيفُ مَوْعِدَ...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: مفاوضات
# attribute: text
# attribute value:  الينابيع والورد كان...
# unrecognized character:
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: M
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: a
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: d
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: e
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: i
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: n
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: H
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: e
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: b
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: r
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: o
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: n
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: M
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: a
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: d
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: e
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: i
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: n
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: H
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: a
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: i
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: f
#
# author name: عز الدين المناصرة
# poem name: مطر حامض
# attribute: text
# attribute value: الأغاني التي عذّبتْن...
# unrecognized character: a
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character:
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character:
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻤ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﺎ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﺛ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character:
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character:
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character:
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﺛ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: هاجمتني الضباع
# attribute: text
# attribute value: هاجمتني الضباعُ مع ا...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻭ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﺑ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قفا نبك
# attribute: text
# attribute value: يا ساكناً سِقْطَ الل...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﺛ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﺛ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻬ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻬ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﺇ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻰ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﺑ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻬ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﺎ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: قمر جرش كان حزينا
# attribute: text
# attribute value: آنَ يا منـزلاً عند ب...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: يتوهج كنعان
# attribute: text
# attribute value: بطيءٌ بريدكَ يا وطني...
# unrecognized character: ﻓ
#
# author name: عز الدين المناصرة
# poem name: يتوهج كنعان
# attribute: text
# attribute value: بطيءٌ بريدكَ يا وطني...
# unrecognized character: ﻲ
#
# author name: عز الدين المناصرة
# poem name: يتوهج كنعان
# attribute: text
# attribute value: بطيءٌ بريدكَ يا وطني...
# unrecognized character: ﻟ
#
# author name: عز الدين المناصرة
# poem name: يتوهج كنعان
# attribute: text
# attribute value: بطيءٌ بريدكَ يا وطني...
# unrecognized character: ﻢ
#
# author name: عز الدين المناصرة
# poem name: يتوهج كنعان
# attribute: text
# attribute value: بطيءٌ بريدكَ يا وطني...
# ...
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: غريب
# attribute: text
# attribute value: غَرِيبٌ تَهُزُّ الْح...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: مواجهة
# attribute: text
# attribute value: خَجِلْتُ لِطُولِ مَا...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: مواجهة
# attribute: text
# attribute value: خَجِلْتُ لِطُولِ مَا...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: مواجهة
# attribute: text
# attribute value: خَجِلْتُ لِطُولِ مَا...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: مواجهة
# attribute: text
# attribute value: خَجِلْتُ لِطُولِ مَا...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: مواجهة
# attribute: text
# attribute value: خَجِلْتُ لِطُولِ مَا...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: مواجهة
# attribute: text
# attribute value: خَجِلْتُ لِطُولِ مَا...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: الحصار
# attribute: text
# attribute value: هَذَا الحِصَارُ الرّ...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: •
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: ﻿
#
# author name: سليم عبدالقادر
# poem name: عائشة..اسم من نور ورحيق
# attribute: text
# attribute value: عَائشةٌ بنتُ الصِّدّ...
# unrecognized character: •
# 100%|████████████████████████████████████████| 936/936 [00:05<00:00, 160.08it/s]
# author name: الطفيل الغنوي
# poem name: بالعفر دار من جميلة هيجت
# attribute: text
# attribute value: بِالعُفرِ دارٌ مِن ج...
# unrecognized character: o
#
# author name: الراعي النميري
# poem name: ضعيف العصا بادي العروق ترى له
# attribute: text
# attribute value: ضَعيفُ العَصا بادي ا...
# unrecognized character: R
#
# author name: الراعي النميري
# poem name: ضعيف العصا بادي العروق ترى له
# attribute: text
# attribute value: ضَعيفُ العَصا بادي ا...
# unrecognized character: I
#
# author name: الراعي النميري
# poem name: ضعيف العصا بادي العروق ترى له
# attribute: text
# attribute value: ضَعيفُ العَصا بادي ا...
# unrecognized character: G
#
# author name: الراعي النميري
# poem name: ضعيف العصا بادي العروق ترى له
# attribute: text
# attribute value: ضَعيفُ العَصا بادي ا...
# unrecognized character: H
#
# author name: الراعي النميري
# poem name: ضعيف العصا بادي العروق ترى له
# attribute: text
# attribute value: ضَعيفُ العَصا بادي ا...
# unrecognized character: T
#
# author name: الراعي النميري
# poem name: ضعيف العصا بادي العروق ترى له
# attribute: text
# attribute value: ضَعيفُ العَصا بادي ا...
# unrecognized character: P
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: C
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: E
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: N
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: T
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: E
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: R
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: C
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: E
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: N
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: T
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: E
#
# author name: جرير
# poem name: إن تضرساني تجدا مضرسا
# attribute: text
# attribute value: إِن تَضرِساني تَجِدا...
# unrecognized character: R
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ی
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ی
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ی
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ی
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ی
#
# author name: الفرزدق
# poem name: يا سائلي أين حلّ الجود و الكرم
# attribute: text
# attribute value: يَا سَـائِلِي‌ أَيْن...
# unrecognized character: ‌

# %%
unknown_chars
# Out:
# {'\xa0': 4701,
#  '\u200f': 1022,
#  'ی': 609,
#  '\u202c': 283,
#  'ﻲ': 279,
#  '\u202e': 279,
#  'ﻓ': 253,
#  '•': 214,
#  'ﻟ': 136,
#  'B': 91,
#  '—': 77,
#  'ٔ': 72,
#  'o': 71,
#  'ﺎ': 59,
#  'ﻢ': 55,
#  'E': 52,
#  '\u200c': 49,
#  '\u200a': 44,
#  'گ': 41,
#  'ﺍ': 40,
#  '\ufeff': 40,
#  'T': 38,
#  'r': 37,
#  'I': 37,
#  'P': 36,
#  'l': 33,
#  'ﺇ': 31,
#  'ﻰ': 31,
#  'c': 31,
#  'ﻭ': 29,
#  'ﻬ': 29,
#  'ﺑ': 29,
#  'R': 29,
#  '□': 29,
#  'a': 28,
#  'F': 27,
#  'L': 24,
#  'e': 22,
#  'i': 22,
#  '\x85': 22,
#  '\u200d': 21,
#  'ﻳ': 21,
#  'ﻴ': 21,
#  '‘': 20,
#  'ٕ': 20,
#  '٭': 18,
#  'M': 18,
#  'ﻣ': 17,
#  'ﻤ': 16,
#  'ﺮ': 16,
#  'ﻥ': 16,
#  'n': 15,
#  'H': 15,
#  'ﺤ': 15,
#  'ﺪ': 15,
#  'ﺛ': 14,
#  'ﺰ': 13,
#  'ﻧ': 13,
#  't': 13,
#  'ﻨ': 12,
#  'ﺃ': 12,
#  'A': 12,
#  's': 11,
#  'G': 11,
#  '−': 11,
#  'چ': 10,
#  'ﻮ': 10,
#  'ﻦ': 10,
#  'ﻗ': 10,
#  'Q': 10,
#  'U': 10,
#  'C': 9,
#  'N': 9,
#  'ﺒ': 9,
#  'ﺣ': 9,
#  'd': 8,
#  'ک': 7,
#  'ﺴ': 7,
#  'ﺗ': 7,
#  'ﻌ': 7,
#  'ﻘ': 7,
#  'b': 6,
#  'u': 6,
#  'ﺼ': 6,
#  'ﻛ': 6,
#  'ﻜ': 6,
#  'ﭐ': 6,
#  'W': 5,
#  'O': 5,
#  'S': 5,
#  'ﺡ': 5,
#  'ﺘ': 5,
#  'ﺖ': 5,
#  'ﺀ': 5,
#  'ﻖ': 5,
#  'ﺻ': 5,
#  'ﺄ': 5,
#  'ﺔ': 5,
#  'ﺭ': 5,
#  'ﭑ': 5,
#  'پ': 5,
#  'ﺬ': 4,
#  'm': 4,
#  'p': 4,
#  'K': 4,
#  'y': 4,
#  'V': 4,
#  'ﻃ': 4,
#  'ﻠ': 4,
#  'ﺟ': 4,
#  'ﻞ': 4,
#  'ﻋ': 4,
#  'ﻼ': 4,
#  'ﺳ': 4,
#  'ٓ': 4,
#  'ﻷ': 3,
#  'h': 3,
#  '\xad': 3,
#  'ﻊ': 3,
#  'ﻒ': 3,
#  'ﺠ': 3,
#  'ﺕ': 3,
#  'ﻔ': 3,
#  'ﺓ': 3,
#  'ﻐ': 3,
#  'ﻩ': 3,
#  'ٱ': 3,
#  'ﭭ': 3,
#  'f': 2,
#  '\u2003': 2,
#  'g': 2,
#  'D': 2,
#  'x': 2,
#  'k': 2,
#  'X': 2,
#  '\x9e': 2,
#  'º': 2,
#  'ﻏ': 2,
#  'ﺩ': 2,
#  'ﻪ': 2,
#  'ﺿ': 2,
#  'ﻄ': 2,
#  'ﺯ': 2,
#  'ﻡ': 2,
#  'ﻕ': 2,
#  'ﻚ': 2,
#  '\x96': 1,
#  '·': 1,
#  'v': 1,
#  'é': 1,
#  '《': 1,
#  '》': 1,
#  '\x01': 1,
#  'q': 1,
#  'ﻫ': 1,
#  'ﺲ': 1,
#  'ﺺ': 1,
#  'ﻑ': 1,
#  'ﻸ': 1,
#  'ﺢ': 1,
#  'ﻉ': 1,
#  'ﻯ': 1,
#  'ﺶ': 1,
#  'ﻀ': 1,
#  'ﺸ': 1,
#  'ﺜ': 1,
#  'ﺷ': 1,
#  'ﺊ': 1,
#  'ﺧ': 1,
#  'ﺫ': 1,
#  'ﺵ': 1,
#  'ﺨ': 1,
#  'w': 1,
#  '\u2029': 1,
#  'ﭬ': 1,
#  '﴿': 1,
#  '﴾': 1}

# %% [markdown]
# # Map from other Arabic formats to plain Arabic

# %%
chars_map = {
    'ﭬ': 'ف',
    'ﺧ': 'خ',
    'ﺊ': 'ئ',
    'ﺷ': 'ش',
    'ﺜ': 'ث',
    'ﺸ': 'ش',
    'ﻀ': 'ض',
    'ﺶ': 'ش',
    'ﻯ': 'ى',
    'ﻉ': 'ع',
    'ﺢ': 'خ',
    'ﻸ': 'لأ',
    'ﻑ': 'ف',
    'ﺺ': 'ص',
    'ﺲ': 'س',
    'ﻫ': 'ه',
    'ﻚ': 'ك',
    'ﻕ': 'ق',
    'ﻡ': 'م',
    'ﺯ': 'ز',
    'ﺿ': 'ض',
    'ﻪ': 'ه',
    'ﻏ': 'غ',
    'ﺩ': 'د',
    'ﭭ': 'ف',
    'ﻩ': 'ه',
    'ﻐ': 'غ',
    'ﺓ': 'ة',
    'ﻔ': 'ف',
    'ﺕ': 'ت',
    'ﺠ': 'ج',
    'ﻒ': 'ف',
    'ﻊ': 'ع',
    'ﻷ': 'لأ',
    'ﺳ': 'س',
    'ﻼ': 'لا',
    'ﻋ': 'ء',
    'ﻞ': 'ل',
    'ﻠ': 'ل',
    'ﺟ': 'ج',
    'ﻃ': 'ط',
    'ﺬ': 'ذ',
    'پ': 'ب',
    'ﭑ': 'آ',
    'ﺭ': 'ر',
    'ﺔ': 'ة',
    'ﺄ': 'أ',
    'ﺻ': 'ص',
    'ﻖ': 'ق',
    'ﺀ': 'ء',
    'ﺖ': 'ت',
    'ﺘ': 'ت',
    'ﺡ': 'ح',
    'ﭐ': 'آ',
    'ﻜ': 'ك',
    'ﻛ': 'ك',
    'ﺼ': 'ص',
    'ﻘ': 'ق',
    'ﻌ': 'ع',
    'ﺗ': 'ت',
    'ﺴ': 'س',
    'ک': 'ك',
    'ﺣ': 'ح',
    'ﺒ': 'ب',
    'ﻗ': 'ق',
    'ﻲ': 'ي',
    'ﻓ': 'ف',
    'ﻟ': 'ل',
    'ﺎ': 'ا',
    'ﻢ': 'م',
    'گ': 'ك',
    'ﺇ' : 'إ',
    'ﻰ': 'ى',
    'ﻭ': 'و',
    'ﻬ': 'ه',
    'ﺑ': 'ب',
    'ﻳ': 'ي',
    'ﻴ': 'ي',
    'ﻣ': 'م',
    'ﻤ': 'م',
    'ﺮ': 'ر',
    'ﻥ': 'ن',
    'ﺤ': 'ح',
    'ﺪ': 'د',
    'ﺛ': 'ث',
    'ﺰ': 'ز',
    'ﻧ': 'ن',
    'ﺃ': 'أ',
    'چ': 'ج',
    'ﻮ': 'و',
    'ﻦ': 'ن',
    'ﻲ': 'ي',
}

# %%
def convert_poems_to_arabic(aldiwan_dict, chars_map):
    for author_name, author_atts in tqdm(aldiwan_dict.items()):
        for poem_name, poem_atts in author_atts["poems"].items():
            text_new = ""
            for c in poem_atts["text"]:
                if c in astring.printable:
                    text_new += c
                elif c in chars_map:
                    text_new += chars_map[c]
            aldiwan_dict[author_name]["poems"][poem_name]["text"] = text_new
                    
    return aldiwan_dict

# %%
clean_dict = convert_poems_to_arabic(aldiwan_dict, chars_map)
# Out:
# 100%|█████████████████████████████████████████| 936/936 [00:10<00:00, 89.74it/s]

# %%
unknown_chars = validate_poems_att(clean_dict, "text", verbose=1)
# Out:
# 100%|████████████████████████████████████████| 936/936 [00:05<00:00, 164.20it/s]
# All poems text fields are valid

# %%
with open("aldiwan_clean_0.json", "w") as f:
    json.dump(clean_dict, f, indent=4)
